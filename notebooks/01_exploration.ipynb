# %% [markdown]
# # Exploration
#
# This notebook is your **workshop**: a place to look at data and try ideas. Notice that it *imports from* `ml_project`, the package in `src/`. It does not define the real logic itself.
#
# The rule: once something here works and you'll reuse it, move it into `src/ml_project/` as a function. The notebook drives your code; it is not your code.

# %%
# Import from the package, not from another notebook.
from ml_project.data import load_data
from ml_project.features import build_features

# Once you've implemented these in src/ml_project/, uncomment and explore:
# df = load_data()
# X, y = build_features(df)
# df.head()
